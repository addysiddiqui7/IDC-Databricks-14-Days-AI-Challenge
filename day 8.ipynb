# %% [markdown]
# ### DAY 8 (16/01/26) – Unity Catalog Governance
#
# ### Learn:
#
# - Catalog → Schema → Table hierarchy
# - Access control (GRANT/REVOKE)
# - Data lineage
# - Managed vs external tables
#
# ### 🛠️ Tasks:
#
# 1. Create catalog & schemas
# 2. Register Delta tables
# 3. Set up permissions
# 4. Create views for controlled access

# %% [markdown]
# ## Task 1 — Create Catalog & Schema

# %%
# %sql
--create catalog and schema..

-- Ensure catalog exists
CREATE CATALOG IF NOT EXISTS ecommerce_catalog;

-- Use catalog
USE CATALOG ecommerce_catalog;

-- Create analytics schema (governed layer)
CREATE SCHEMA IF NOT EXISTS analytics;


-- now this will works -> ecommerce_catalog.analytics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW TABLES IN ecommerce_catalog.default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>events_bronze</td><td>false</td></tr><tr><td>default</td><td>events_gold</td><td>false</td></tr><tr><td>default</td><td>events_silver</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ## Task 2 — Register existing Delta tables

# %%
# %sql
CREATE TABLE ecommerce_catalog.analytics.events_bronze
USING DELTA
AS
SELECT * FROM ecommerce_catalog.default.events_bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE ecommerce_catalog.analytics.events_silver
USING DELTA
AS
SELECT * FROM ecommerce_catalog.default.events_silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE ecommerce_catalog.analytics.events_gold
USING DELTA
AS
SELECT * FROM ecommerce_catalog.default.events_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 3 — Set up permissions (Access Control)

# %% [markdown]
# Analysts → read-only on Gold

# %%
# %sql
GRANT SELECT
ON TABLE ecommerce_catalog.analytics.events_gold
TO `addysiddiqui7@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 4 — Create views for controlled access

# %%
# %sql
CREATE OR REPLACE VIEW ecommerce_catalog.analytics.vw_product_metrics AS
SELECT
    product_id,
    brand,
    category_code,
    views,
    carts,
    purchases,
    revenue,
    conversion_rate_pct,
    avg_order_value
FROM ecommerce_catalog.analytics.events_gold;

# %%
# %sql
GRANT SELECT
ON VIEW ecommerce_catalog.analytics.vw_product_metrics
TO `addysiddiqui7@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
